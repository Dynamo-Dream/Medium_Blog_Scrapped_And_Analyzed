# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("MediumBlogScrapped.csv")

# %%
df.head()
# Out:
#                                       title         Author Upvote  \
# 0                      DrivenData Interview  Will Koehrsen    544
# 1               A Data Science Conversation  Will Koehrsen    411
# 2     12 Lessons from 55,000 pages of books  Will Koehrsen   1.4K
# 3                             Books of 2019  Will Koehrsen    464
# 4  “Just Do It” Won’t Get You to Your Goals  Will Koehrsen    398
#
#    CommentCount  Publish Date    Read Time  \
# 0             2  Dec 14, 2020  13 min read
# 1            43  Mar 10, 2020   3 min read
# 2            10   Jan 2, 2020  14 min read
# 3             1   Jan 1, 2020  58 min read
# 4             2  Dec 27, 2019  12 min read
#
#                                            Paragraph  \
# 0  In October 2020, I was interviewed by DrivenDa...
# 1  Talking is a lot like writing in that it force...
# 2  Reading 136 books in a year does not get you t...
# 3  Before we get started: reading books does not ...
# 4  Rule number one for achieving goals: don’t tak...
#
#                                                Links           Tag
# 0  https://williamkoehrsen.medium.com/drivendata-...  Data Science
# 1  https://williamkoehrsen.medium.com/a-data-scie...  Data Science
# 2  https://williamkoehrsen.medium.com/12-lessons-...       Reading
# 3  https://williamkoehrsen.medium.com/books-of-20...       Reading
# 4  https://williamkoehrsen.medium.com/just-do-it-...  Productivity

# %%
columns = df.columns
columns
# Out:
# Index(['title', 'Author', 'Upvote', 'CommentCount', 'Publish Date',
#        'Read Time', 'Paragraph', 'Links', 'Tag'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# title           0
# Author          0
# Upvote          0
# CommentCount    0
# Publish Date    0
# Read Time       0
# Paragraph       0
# Links           0
# Tag             0
# dtype: int64

# %%
df.dtypes
# Out:
# title           object
# Author          object
# Upvote          object
# CommentCount     int64
# Publish Date    object
# Read Time       object
# Paragraph       object
# Links           object
# Tag             object
# dtype: object

# %% [markdown]
# ### Conversion Of Data Types

# %%
def convert_to_int(x):
    """
    Function Name: convert_to_int
    Parameters:
        x (str): A string representing a number, potentially suffixed with 'K' for thousands.
    Returns:
        int: An integer value converted from the input string.
    """
    if 'K' in x:
        return int(float(x.replace('K', '')) * 1000)
    else:
        return int(x)

# %%
df['Upvote'] = df['Upvote'].apply(convert_to_int)

# %%
df['Upvote'].head() ## Converted Upvote to int64
# Out:
# 0     544
# 1     411
# 2    1400
# 3     464
# 4     398
# Name: Upvote, dtype: int64

# %%
def convert_read_time(x):
    """
    Function Name: convert_read_time
    Parameters:
        x (str): A string representing a read time, typically in a format like "5 min" or "10 mins".
    Returns:
        int: An integer value representing the read time extracted from the input string.
    """
    x = x.split(" ")[0]
    return int(x)

# %%
df['Read Time'] = df["Read Time"].apply(convert_read_time)

# %%
df['Read Time'].head() # Converted Read Time
# Out:
# 0    13
# 1     3
# 2    14
# 3    58
# 4    12
# Name: Read Time, dtype: int64

# %%
from datetime import datetime # importing Datetime to Convert Publish Date

# %%
def process_date(date_str):
    """
    Function Name: process_date
    Parameters:
        date_str (str): A string representing a date in the format '%b %d, %Y' (e.g., 'Jan 01, 2023').
    Returns:
        tuple: A tuple containing formatted date, weekday, month, and year.
    """
    date_obj = datetime.strptime(date_str, '%b %d, %Y')
    weekday = date_obj.strftime('%A')
    formatted_date = date_obj.strftime('%d %b %Y')
    month = date_obj.strftime('%B')
    year = date_obj.year
    return formatted_date, weekday, month, year

# %%
df['Publish Date'], df['Weekday'], df['Month'], df['Year'] = zip(*df['Publish Date'].apply(process_date))

# %%
df.head(3)
# Out:
#                                    title         Author  Upvote  CommentCount  \
# 0                   DrivenData Interview  Will Koehrsen     544             2
# 1            A Data Science Conversation  Will Koehrsen     411            43
# 2  12 Lessons from 55,000 pages of books  Will Koehrsen    1400            10
#
#   Publish Date  Read Time                                          Paragraph  \
# 0  14 Dec 2020         13  In October 2020, I was interviewed by DrivenDa...
# 1  10 Mar 2020          3  Talking is a lot like writing in that it force...
# 2  02 Jan 2020         14  Reading 136 books in a year does not get you t...
#
#                                                Links           Tag   Weekday  \
# 0  https://williamkoehrsen.medium.com/drivendata-...  Data Science    Monday
# 1  https://williamkoehrsen.medium.com/a-data-scie...  Data Science   Tuesday
# 2  https://williamkoehrsen.medium.com/12-lessons-...       Reading  Thursday
#
#       Month  Year
# 0  December  2020
# 1     March  2020
# 2   January  2020

# %%
def blog_length(blog):
    """
    Function Name: blog_length
    Parameters:
        blog (str): A string representing a blog post.
    Returns:
        int: The length of the blog post.
    """
    return len(blog)

# %%
df["BlogLength"] = df["Paragraph"].apply(blog_length)

# %%
df.head(2)
# Out:
#                          title         Author  Upvote  CommentCount  \
# 0         DrivenData Interview  Will Koehrsen     544             2
# 1  A Data Science Conversation  Will Koehrsen     411            43
#
#   Publish Date  Read Time                                          Paragraph  \
# 0  14 Dec 2020         13  In October 2020, I was interviewed by DrivenDa...
# 1  10 Mar 2020          3  Talking is a lot like writing in that it force...
#
#                                                Links           Tag  Weekday  \
# 0  https://williamkoehrsen.medium.com/drivendata-...  Data Science   Monday
# 1  https://williamkoehrsen.medium.com/a-data-scie...  Data Science  Tuesday
#
#       Month  Year  BlogLength
# 0  December  2020       15939
# 1     March  2020        1379

# %%
df
# Out:
#                                                  title         Author  Upvote  \
# 0                                 DrivenData Interview  Will Koehrsen     544
# 1                          A Data Science Conversation  Will Koehrsen     411
# 2                12 Lessons from 55,000 pages of books  Will Koehrsen    1400
# 3                                        Books of 2019  Will Koehrsen     464
# 4             “Just Do It” Won’t Get You to Your Goals  Will Koehrsen     398
# ..                                                 ...            ...     ...
# 150                               The Triumph of Peace  Will Koehrsen    7900
# 151                                 Home of the Scared  Will Koehrsen    7900
# 152  Capstone Project: Mercedes-Benz Greener Manufa...  Will Koehrsen     120
# 153          The Vanquishing of War, Plague and Famine  Will Koehrsen      70
# 154    Screw the Environment, but Consider Your Wallet  Will Koehrsen       7
#
#      CommentCount Publish Date  Read Time  \
# 0               2  14 Dec 2020         13
# 1              43  10 Mar 2020          3
# 2              10  02 Jan 2020         14
# 3               1  01 Jan 2020         58
# 4               2  27 Dec 2019         12
# ..            ...          ...        ...
# 150            43  05 Jul 2017         14
# 151            43  01 Jul 2017          9
# 152            43  30 Jun 2017         42
# 153            43  18 Jun 2017         14
# 154            43  11 Jun 2017          7
#
#                                              Paragraph  \
# 0    In October 2020, I was interviewed by DrivenDa...
# 1    Talking is a lot like writing in that it force...
# 2    Reading 136 books in a year does not get you t...
# 3    Before we get started: reading books does not ...
# 4    Rule number one for achieving goals: don’t tak...
# ..                                                 ...
# 150  A review of The Better Angels of Our Nature: W...
# 151  A review of A Culture of Fear: Why Americans a...
# 152  Author’s Note: This is the report I completed ...
# 153  Part 1 of the Optimist’s Guide to the 21st Cen...
# 154  When the Health of the Environment and the Hea...
#
#                                                  Links               Tag  \
# 0    https://williamkoehrsen.medium.com/drivendata-...      Data Science
# 1    https://williamkoehrsen.medium.com/a-data-scie...      Data Science
# 2    https://williamkoehrsen.medium.com/12-lessons-...           Reading
# 3    https://williamkoehrsen.medium.com/books-of-20...           Reading
# 4    https://williamkoehrsen.medium.com/just-do-it-...      Productivity
# ..                                                 ...               ...
# 150  https://williamkoehrsen.medium.com/the-triumph...             Books
# 151  https://williamkoehrsen.medium.com/home-of-the...          Politics
# 152  https://williamkoehrsen.medium.com/capstone-pr...  Machine Learning
# 153  https://williamkoehrsen.medium.com/the-vanquis...    Climate Change
# 154  https://williamkoehrsen.medium.com/screw-the-e...    Climate Change
#
#        Weekday     Month  Year  BlogLength
# 0       Monday  December  2020       15939
# 1      Tuesday     March  2020        1379
# 2     Thursday   January  2020       20927
# 3    Wednesday   January  2020       15010
# 4       Friday  December  2019       12708
# ..         ...       ...   ...         ...
# 150  Wednesday      July  2017       11006
# 151   Saturday      July  2017       12404
# 152     Friday      June  2017       66826
# 153     Sunday      June  2017       20856
# 154     Sunday      June  2017        9516
#
# [155 rows x 13 columns]

# %%
df["Tag"].value_counts()
# Out:
# Tag
# Data Science            48
# Machine Learning        46
# Programming              6
# Python                   5
# Books                    4
# Data                     4
# Education                4
# Statistics               3
# Reading                  3
# Data Visualization       3
# Climate Change           3
# Tech                     2
# Big Data                 2
# Self Improvement         2
# Psychology               2
# Space                    1
# Motivation               1
# History                  1
# Technology               1
# Privacy                  1
# College                  1
# Social Media             1
# Growth Mindset           1
# Web Development          1
# Apache Spark             1
# Software Development     1
# Docker                   1
# Productivity             1
# Science                  1
# The Reality Project      1
# Health                   1
# Running                  1
# Politics                 1
# Name: count, dtype: int64

# %% [markdown]
# The Dataset is highly imbalanced and many similar topic are categorised as different therefore

# %%
#Mapping the similar kind of Topic Into One
tag_mapping = {
    'Data Science': 'Data Science',
    'Machine Learning': 'Machine Learning',
    'Programming': 'Programming',
    'Python': 'Programming',
    'Books': 'Personal Development',
    'Data': 'Data Science',
    'Education': 'Education',
    'Statistics': 'Data Science',
    'Reading': 'Personal Development',
    'Data Visualization': 'Data Science',
    'Climate Change': 'Education',
    'Tech': 'Technology',
    'Big Data': 'Data Science',
    'Self Improvement': 'Personal Development',
    'Psychology': 'Education',
    'Space': 'Education',
    'Motivation': 'Personal Development',
    'History': 'Education',
    'Technology': 'Technology',
    'Privacy': 'Technology',
    'College': 'Education',
    'Social Media': 'Technology',
    'Growth Mindset': 'Personal Development',
    'Web Development': 'Technology',
    'Apache Spark': 'Technology',
    'Software Development': 'Technology',
    'Docker': 'Technology',
    'Productivity': 'Personal Development',
    'Science': 'Education',
    'The Reality Project': 'Education',
    'Health': 'Personal Development',
    'Running': 'Personal Development',
    'Politics': 'Education'
}

df['Tag'] = df['Tag'].map(tag_mapping)

# %%
df['Tag'].value_counts()
# Out:
# Tag
# Data Science            60
# Machine Learning        46
# Education               15
# Personal Development    14
# Programming             11
# Technology               9
# Name: count, dtype: int64

# %%
df.to_csv('MediumDataAfterEDA.csv',index=False)
